# %% [markdown]
# #### **Training an ANN Model on Rice Type Classification**

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset , DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
df = pd.read_csv("E:\\Notes\\Python'\\PyTorch\\Datasets\\riceClassification.csv")
df.head()
# Out:
#    id  Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0   1  4537        92.229316        64.012769      0.719916        4677
# 1   2  2872        74.691881        51.400454      0.725553        3015
# 2   3  3048        76.293164        52.043491      0.731211        3132
# 3   4  3073        77.033628        51.928487      0.738639        3157
# 4   5  3693        85.124785        56.374021      0.749282        3802
#
#    EquivDiameter    Extent  Perimeter  Roundness  AspectRation  Class
# 0      76.004525  0.657536    273.085   0.764510      1.440796      1
# 1      60.471018  0.713009    208.317   0.831658      1.453137      1
# 2      62.296341  0.759153    210.012   0.868434      1.465950      1
# 3      62.551300  0.783529    210.657   0.870203      1.483456      1
# 4      68.571668  0.769375    230.332   0.874743      1.510000      1

# %%
df.isna().sum()
df.drop(columns=["id"], axis=1, inplace=True)
df.head()
# Out:
#    Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0  4537        92.229316        64.012769      0.719916        4677
# 1  2872        74.691881        51.400454      0.725553        3015
# 2  3048        76.293164        52.043491      0.731211        3132
# 3  3073        77.033628        51.928487      0.738639        3157
# 4  3693        85.124785        56.374021      0.749282        3802
#
#    EquivDiameter    Extent  Perimeter  Roundness  AspectRation  Class
# 0      76.004525  0.657536    273.085   0.764510      1.440796      1
# 1      60.471018  0.713009    208.317   0.831658      1.453137      1
# 2      62.296341  0.759153    210.012   0.868434      1.465950      1
# 3      62.551300  0.783529    210.657   0.870203      1.483456      1
# 4      68.571668  0.769375    230.332   0.874743      1.510000      1

# %%
df["Class"].unique()
# Out:
# array([1, 0])

# %%
original_df = df.copy()

for column in df.columns:
    df[column] = df[column]/df[column].abs().max()  # Normalizing

df.head()
# Out:
#        Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0  0.444368         0.503404         0.775435      0.744658    0.424873
# 1  0.281293         0.407681         0.622653      0.750489    0.273892
# 2  0.298531         0.416421         0.630442      0.756341    0.284520
# 3  0.300979         0.420463         0.629049      0.764024    0.286791
# 4  0.361704         0.464626         0.682901      0.775033    0.345385
#
#    EquivDiameter    Extent  Perimeter  Roundness  AspectRation  Class
# 0       0.666610  0.741661   0.537029   0.844997      0.368316    1.0
# 1       0.530370  0.804230   0.409661   0.919215      0.371471    1.0
# 2       0.546380  0.856278   0.412994   0.959862      0.374747    1.0
# 3       0.548616  0.883772   0.414262   0.961818      0.379222    1.0
# 4       0.601418  0.867808   0.452954   0.966836      0.386007    1.0

# %%
X = df.iloc[:,:-1].values  # .values -> converts pandas to numpy df which is then passed to dataset
y = df.iloc[:, -1].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.5)

print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
# Out:
# (12729, 10)
# (2728, 10)
# (2728, 10)

# %%
# Custom Dataset

class CustomDataset(Dataset):

    def __init__(self, features, labels):
        self.features = torch.tensor(features, dtype=torch.float32).to(device)
        self.labels = torch.tensor(labels, dtype=torch.long).to(device)

    def __len__(self):
        return len(self.features)
    
    def __getitem__(self, index):
        return self.features[index], self.labels[index]

# %%
training_data = CustomDataset(X_train, y_train)
validation_data = CustomDataset(X_val, y_val)
test_data = CustomDataset(X_test, y_test)

# %%
train_loader = DataLoader(training_data, batch_size=32, shuffle=True)
val_loader = DataLoader(validation_data, batch_size=32, shuffle=True)
test_loader = DataLoader(test_data, batch_size=32, shuffle=False)

# %%
# Model Architecture

class NN(nn.Module):

    def __init__(self, num_features):

        super().__init__()

        self.model = nn.Sequential(
            nn.Linear(num_features, 64),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Dropout(p=0.3),
            nn.Linear(64,10),
            nn.BatchNorm1d(10),
            nn.ReLU(),
            nn.Dropout(p=0.3),
            nn.Linear(10,2)
        )

    def forward(self,x):
        return self.model(x)

# %%
Epochs = 100
Learning_rate=1e-3

# %%
X_train.shape[1]
# Out:
# 10

# %%
model = NN(X_train.shape[1])
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=Learning_rate)

# %%
# Training Loop 

for epoch in range(Epochs):

    model.train()
    running_train_loss=0.0
    correct=0.0
    total = 0.0

    for batch_features, batch_labels in train_loader:

        batch_features, batch_labels = batch_features.to(device), batch_labels.to(device)

        optimizer.zero_grad()
        output = model(batch_features)
        loss = criterion(output, batch_labels)
        loss.backward()
        optimizer.step()

        running_train_loss += loss.item()

    with torch.no_grad():
        for batch_features, batch_labels in val_loader:

            batch_features, batch_labels = batch_features.to(device), batch_labels.to(device)
            output = model(batch_features)
            _, pred = torch.max(output , 1)

            total += batch_labels.shape[0]
            correct += (pred == batch_labels).sum().item()




    avg_train_loss = running_train_loss/len(train_loader)
    val_accuacry = correct/total
    print(f'Epoch: {epoch+1}, Training Loss: {avg_train_loss:.4f}, Validation Accuracy: {val_accuacry * 100}')
# Out:
# Epoch: 1, Training Loss: 0.0691, Validation Accuracy: 98.53372434017595
# Epoch: 2, Training Loss: 0.0689, Validation Accuracy: 98.46041055718476
# Epoch: 3, Training Loss: 0.0691, Validation Accuracy: 98.27712609970675
# Epoch: 4, Training Loss: 0.0685, Validation Accuracy: 98.60703812316716
# Epoch: 5, Training Loss: 0.0657, Validation Accuracy: 98.31378299120234
# Epoch: 6, Training Loss: 0.0660, Validation Accuracy: 98.16715542521995
# Epoch: 7, Training Loss: 0.0697, Validation Accuracy: 98.71700879765396
# Epoch: 8, Training Loss: 0.0675, Validation Accuracy: 98.42375366568915
# Epoch: 9, Training Loss: 0.0662, Validation Accuracy: 98.57038123167156
# Epoch: 10, Training Loss: 0.0671, Validation Accuracy: 98.53372434017595
# Epoch: 11, Training Loss: 0.0672, Validation Accuracy: 98.09384164222874
# Epoch: 12, Training Loss: 0.0715, Validation Accuracy: 98.09384164222874
# Epoch: 13, Training Loss: 0.0697, Validation Accuracy: 98.71700879765396
# Epoch: 14, Training Loss: 0.0703, Validation Accuracy: 98.02052785923753
# Epoch: 15, Training Loss: 0.0679, Validation Accuracy: 98.68035190615836
# Epoch: 16, Training Loss: 0.0663, Validation Accuracy: 98.46041055718476
# Epoch: 17, Training Loss: 0.0688, Validation Accuracy: 98.64369501466275
# Epoch: 18, Training Loss: 0.0630, Validation Accuracy: 98.49706744868035
# Epoch: 19, Training Loss: 0.0671, Validation Accuracy: 98.38709677419355
# Epoch: 20, Training Loss: 0.0672, Validation Accuracy: 98.53372434017595
# Epoch: 21, Training Loss: 0.0624, Validation Accuracy: 98.05718475073314
# Epoch: 22, Training Loss: 0.0672, Validation Accuracy: 98.27712609970675
# Epoch: 23, Training Loss: 0.0700, Validation Accuracy: 98.75366568914956
# Epoch: 24, Training Loss: 0.0691, Validation Accuracy: 98.53372434017595
# Epoch: 25, Training Loss: 0.0656, Validation Accuracy: 98.24046920821115
# Epoch: 26, Training Loss: 0.0705, Validation Accuracy: 98.49706744868035
# Epoch: 27, Training Loss: 0.0711, Validation Accuracy: 98.46041055718476
# Epoch: 28, Training Loss: 0.0659, Validation Accuracy: 98.42375366568915
# Epoch: 29, Training Loss: 0.0682, Validation Accuracy: 98.35043988269796
# Epoch: 30, Training Loss: 0.0682, Validation Accuracy: 98.27712609970675
# Epoch: 31, Training Loss: 0.0690, Validation Accuracy: 98.53372434017595
# Epoch: 32, Training Loss: 0.0644, Validation Accuracy: 98.27712609970675
# Epoch: 33, Training Loss: 0.0700, Validation Accuracy: 98.24046920821115
# Epoch: 34, Training Loss: 0.0646, Validation Accuracy: 98.68035190615836
# Epoch: 35, Training Loss: 0.0676, Validation Accuracy: 98.13049853372434
# Epoch: 36, Training Loss: 0.0663, Validation Accuracy: 98.46041055718476
# Epoch: 37, Training Loss: 0.0657, Validation Accuracy: 98.16715542521995
# Epoch: 38, Training Loss: 0.0667, Validation Accuracy: 98.46041055718476
# Epoch: 39, Training Loss: 0.0655, Validation Accuracy: 98.16715542521995
# Epoch: 40, Training Loss: 0.0632, Validation Accuracy: 98.53372434017595
# Epoch: 41, Training Loss: 0.0656, Validation Accuracy: 98.46041055718476
# Epoch: 42, Training Loss: 0.0680, Validation Accuracy: 98.38709677419355
# Epoch: 43, Training Loss: 0.0617, Validation Accuracy: 98.57038123167156
# Epoch: 44, Training Loss: 0.0656, Validation Accuracy: 98.60703812316716
# Epoch: 45, Training Loss: 0.0665, Validation Accuracy: 98.46041055718476
# Epoch: 46, Training Loss: 0.0614, Validation Accuracy: 98.46041055718476
# Epoch: 47, Training Loss: 0.0646, Validation Accuracy: 98.35043988269796
# Epoch: 48, Training Loss: 0.0650, Validation Accuracy: 98.60703812316716
# Epoch: 49, Training Loss: 0.0666, Validation Accuracy: 98.46041055718476
# Epoch: 50, Training Loss: 0.0681, Validation Accuracy: 98.46041055718476
# Epoch: 51, Training Loss: 0.0641, Validation Accuracy: 98.09384164222874
# Epoch: 52, Training Loss: 0.0636, Validation Accuracy: 98.49706744868035
# Epoch: 53, Training Loss: 0.0666, Validation Accuracy: 98.31378299120234
# Epoch: 54, Training Loss: 0.0682, Validation Accuracy: 98.57038123167156
# Epoch: 55, Training Loss: 0.0654, Validation Accuracy: 98.79032258064517
# Epoch: 56, Training Loss: 0.0658, Validation Accuracy: 98.46041055718476
# Epoch: 57, Training Loss: 0.0650, Validation Accuracy: 98.20381231671554
# Epoch: 58, Training Loss: 0.0632, Validation Accuracy: 98.71700879765396
# Epoch: 59, Training Loss: 0.0612, Validation Accuracy: 98.71700879765396
# Epoch: 60, Training Loss: 0.0630, Validation Accuracy: 98.60703812316716
# Epoch: 61, Training Loss: 0.0667, Validation Accuracy: 98.16715542521995
# Epoch: 62, Training Loss: 0.0649, Validation Accuracy: 98.20381231671554
# Epoch: 63, Training Loss: 0.0690, Validation Accuracy: 98.27712609970675
# Epoch: 64, Training Loss: 0.0624, Validation Accuracy: 98.53372434017595
# Epoch: 65, Training Loss: 0.0616, Validation Accuracy: 98.82697947214076
# Epoch: 66, Training Loss: 0.0645, Validation Accuracy: 98.31378299120234
# Epoch: 67, Training Loss: 0.0622, Validation Accuracy: 98.68035190615836
# Epoch: 68, Training Loss: 0.0650, Validation Accuracy: 98.57038123167156
# Epoch: 69, Training Loss: 0.0634, Validation Accuracy: 98.35043988269796
# Epoch: 70, Training Loss: 0.0665, Validation Accuracy: 98.38709677419355
# Epoch: 71, Training Loss: 0.0632, Validation Accuracy: 98.71700879765396
# Epoch: 72, Training Loss: 0.0633, Validation Accuracy: 98.60703812316716
# Epoch: 73, Training Loss: 0.0657, Validation Accuracy: 98.20381231671554
# Epoch: 74, Training Loss: 0.0628, Validation Accuracy: 98.31378299120234
# Epoch: 75, Training Loss: 0.0629, Validation Accuracy: 98.42375366568915
# Epoch: 76, Training Loss: 0.0613, Validation Accuracy: 98.27712609970675
# Epoch: 77, Training Loss: 0.0649, Validation Accuracy: 98.90029325513197
# Epoch: 78, Training Loss: 0.0647, Validation Accuracy: 98.71700879765396
# Epoch: 79, Training Loss: 0.0643, Validation Accuracy: 98.46041055718476
# Epoch: 80, Training Loss: 0.0653, Validation Accuracy: 98.38709677419355
# Epoch: 81, Training Loss: 0.0634, Validation Accuracy: 98.46041055718476
# Epoch: 82, Training Loss: 0.0636, Validation Accuracy: 98.31378299120234
# Epoch: 83, Training Loss: 0.0651, Validation Accuracy: 98.60703812316716
# Epoch: 84, Training Loss: 0.0648, Validation Accuracy: 98.20381231671554
# Epoch: 85, Training Loss: 0.0637, Validation Accuracy: 98.79032258064517
# Epoch: 86, Training Loss: 0.0641, Validation Accuracy: 98.46041055718476
# Epoch: 87, Training Loss: 0.0573, Validation Accuracy: 98.16715542521995
# Epoch: 88, Training Loss: 0.0654, Validation Accuracy: 98.49706744868035
# Epoch: 89, Training Loss: 0.0591, Validation Accuracy: 98.60703812316716
# Epoch: 90, Training Loss: 0.0623, Validation Accuracy: 98.31378299120234
# Epoch: 91, Training Loss: 0.0603, Validation Accuracy: 98.75366568914956
# Epoch: 92, Training Loss: 0.0649, Validation Accuracy: 98.64369501466275
# Epoch: 93, Training Loss: 0.0624, Validation Accuracy: 98.31378299120234
# Epoch: 94, Training Loss: 0.0628, Validation Accuracy: 98.35043988269796
# Epoch: 95, Training Loss: 0.0639, Validation Accuracy: 98.24046920821115
# Epoch: 96, Training Loss: 0.0624, Validation Accuracy: 98.38709677419355
# Epoch: 97, Training Loss: 0.0628, Validation Accuracy: 98.42375366568915
# Epoch: 98, Training Loss: 0.0641, Validation Accuracy: 98.42375366568915
# Epoch: 99, Training Loss: 0.0607, Validation Accuracy: 98.68035190615836
# Epoch: 100, Training Loss: 0.0586, Validation Accuracy: 98.53372434017595

# %%
print(test_loader)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x0000028BC3DABE60>

# %%
model.eval()
total=0
correct=0

with torch.no_grad():

    for batch_features, batch_labels in test_loader:
        batch_features, batch_labels = batch_features.to(device), batch_labels.to(device)

        output = model(batch_features)

        _, pred = torch.max(output , 1)

        total += batch_labels.shape[0]
        correct += (pred == batch_labels).sum().item()

accuracy = correct/total
print(f"Accuracy of model on test data: {accuracy:.4f}")
# Out:
# Accuracy of model on test data: 0.9897
